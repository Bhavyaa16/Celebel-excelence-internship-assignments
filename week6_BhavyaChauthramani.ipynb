# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavyaa16/Celebel-excelence-internship-assignments/blob/main/week6_BhavyaChauthramani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import librarires

# %%
import os
import zipfile
import random

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau
)

from tensorflow.keras.optimizers import Adam

from skimage.metrics import (
    peak_signal_noise_ratio,
    structural_similarity
)

print("TensorFlow Version :", tf.__version__)
# Out:
# TensorFlow Version : 2.20.0

# %% [markdown]
# SETING SEED VALUE

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("Random Seed Set Successfully")
# Out:
# Random Seed Set Successfully

# %% [markdown]
# EXTRACTING THE DATASET

# %%
zip_path = "/content/archive (2).zip"

extract_path = "MNIST"

if not os.path.exists(extract_path):

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print("Dataset Extracted Successfully")
# Out:
# Dataset Extracted Successfully

# %% [markdown]
# LOADING THE DATASET

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
def load_images(folder):

    images = []
    labels = []

    for digit in sorted(os.listdir(folder)):

        digit_folder = os.path.join(folder, digit)

        if not os.path.isdir(digit_folder):
            continue

        for image_name in os.listdir(digit_folder):

            image_path = os.path.join(digit_folder, image_name)

            image = Image.open(image_path).convert("L")

            image = np.array(image)

            images.append(image)

            labels.append(int(digit))

    images = np.array(images)
    labels = np.array(labels)

    return images, labels

# %% [markdown]
# SPLITING TRAIN AND TEST DATA

# %%
train_folder = os.path.join(extract_path, "mnist_png", "training")

test_folder = os.path.join(extract_path, "mnist_png", "testing")

print("Train Folder :", train_folder)
print("Test Folder :", test_folder)
# Out:
# Train Folder : MNIST/mnist_png/training
# Test Folder : MNIST/mnist_png/testing

# %%
X_train, y_train = load_images(train_folder)

X_test, y_test = load_images(test_folder)

print("Training Images :", X_train.shape)
print("Testing Images :", X_test.shape)
# Out:
# Training Images : (60000, 28, 28)
# Testing Images : (10000, 28, 28)

# %% [markdown]
# VISUALIZING THE DATASSET

# %%
plt.figure(figsize=(12,4))

for i in range(10):

    plt.subplot(2,5,i+1)

    plt.imshow(X_train[i], cmap="gray")

    plt.title(f"Label : {y_train[i]}")

    plt.axis("off")

plt.tight_layout()

plt.show()

# %% [markdown]
# NORMALISING IMAGES

# %%
X_train = X_train.astype("float32") / 255.0

X_test = X_test.astype("float32") / 255.0

# Add Channel Dimension
X_train = np.expand_dims(X_train, axis=-1)

X_test = np.expand_dims(X_test, axis=-1)

print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %% [markdown]
# GENERATING GAUSSIAN NOISE

# %%
noise_factor = 0.45

train_noise = np.random.normal(
    loc=0.0,
    scale=noise_factor,
    size=X_train.shape
)

test_noise = np.random.normal(
    loc=0.0,
    scale=noise_factor,
    size=X_test.shape
)

X_train_noisy = np.clip(
    X_train + train_noise,
    0.,
    1.
)

X_test_noisy = np.clip(
    X_test + test_noise,
    0.,
    1.
)

print("Noise Added Successfully")
# Out:
# Noise Added Successfully

# %% [markdown]
# VISUALISING NOISE (Original vs Noisy Images)

# %%
plt.figure(figsize=(12,4))

for i in range(5):

    plt.subplot(2,5,i+1)

    plt.imshow(X_train[i].squeeze(), cmap="gray")

    plt.title("Original")

    plt.axis("off")

    plt.subplot(2,5,i+6)

    plt.imshow(X_train_noisy[i].squeeze(), cmap="gray")

    plt.title("Noisy")

    plt.axis("off")

plt.tight_layout()

plt.show()

# %% [markdown]
# CONVOLUTIONAL DENOISING AUTOENCODER

# %%
# Input image size
INPUT_SHAPE = (28, 28, 1)

# input layer
inputs = layers.Input(shape=INPUT_SHAPE, name="Input_Image")

# ENCODER : The encoder compresses the noisy image into latent representation while preserving important features

x = layers.Conv2D(
    filters=32,
    kernel_size=(3,3),
    activation="relu",
    padding="same",
    name="Encoder_Conv1"
)(inputs)

x = layers.MaxPooling2D(
    pool_size=(2,2),
    padding="same",
    name="Encoder_Pool1"
)(x)

# Output Shape -> 14 x 14 x 32

x = layers.Conv2D(
    filters=64,
    kernel_size=(3,3),
    activation="relu",
    padding="same",
    name="Encoder_Conv2"
)(x)

x = layers.MaxPooling2D(
    pool_size=(2,2),
    padding="same",
    name="Encoder_Pool2"
)(x)

# Output Shape -> 7 x 7 x 64


# ----- Latent Space -----
latent = layers.Conv2D(
    filters=128,
    kernel_size=(3,3),
    activation="relu",
    padding="same",
    name="Latent_Space"
)(x)

# Output Shape -> 7 x 7 x 128

print("Encoder Built Successfully")
# Out:
# Encoder Built Successfully

# %% [markdown]
# DECODER

# %%
# DECODER : It reconstructs a clean image from the latent representation

x = layers.Conv2DTranspose(
    filters=64,
    kernel_size=(3,3),
    strides=2,
    padding="same",
    activation="relu",
    name="Decoder_Up1"
)(latent)

# Output -> 14 x 14 x 64

x = layers.Conv2DTranspose(
    filters=32,
    kernel_size=(3,3),
    strides=2,
    padding="same",
    activation="relu",
    name="Decoder_Up2"
)(x)

# Output -> 28 x 28 x 32

outputs = layers.Conv2D(
    filters=1,
    kernel_size=(3,3),
    activation="sigmoid",
    padding="same",
    name="Output_Image"
)(x)

# Create Autoencoder Model
autoencoder = Model(
    inputs=inputs,
    outputs=outputs,
    name="MNIST_Denoising_Autoencoder"
)

print("Decoder Built Successfully")
# Out:
# Decoder Built Successfully

# %% [markdown]
# MODEL SUMMARAY

# %%
autoencoder.summary()
# Out:
# Model: "MNIST_Denoising_Autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input_Image (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoder_Conv1 (Conv2D)          │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoder_Pool1 (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoder_Conv2 (Conv2D)          │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoder_Pool2 (MaxPooling2D)    │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Latent_Space (Conv2D)           │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Decoder_Up1 (Conv2DTranspose)   │ (None, 14, 14, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Decoder_Up2 (Conv2DTranspose)   │ (None, 28, 28, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Image (Conv2D)           │ (None, 28, 28, 1)      │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 185,217 (723.50 KB)
#  Trainable params: 185,217 (723.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# VISUALIZING MODEL ARCHITECTURE

# %%
from tensorflow.keras.utils import plot_model

plot_model(
    autoencoder,
    show_shapes=True,
    show_layer_names=True,
    dpi=120
)

# %% [markdown]
# MODEL COMPILATION

# %%
optimizer = Adam(
    learning_rate=0.001
)

autoencoder.compile(
    optimizer=optimizer,
    loss="binary_crossentropy",
    metrics=["mae"]
)

print("Model Compiled Successfully")
# Out:
# Model Compiled Successfully

# %% [markdown]
# DEFINING CALLBACKS

# %%
#  Callbacks improve training by:
#  1. Saving the best model.
#  2. Reducing learning rate if validation loss stagnates.
#  3. Stopping early to prevent overfitting.

checkpoint = ModelCheckpoint(
    filepath="best_model.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=3,
    verbose=1,
    min_lr=1e-6
)

callbacks = [
    checkpoint,
    early_stop,
    reduce_lr
]

print("Callbacks Ready")
# Out:
# Callbacks Ready

# %% [markdown]
# MODEL TRAINING

# %%
# Training Autoencoder
# Input  : Noisy Images
# Output : Clean Images
# The model learns to remove noise during training.

history = autoencoder.fit(

    X_train_noisy,
    X_train,

    validation_split=0.10,

    epochs=30,

    batch_size=128,

    shuffle=True,

    callbacks=callbacks,

    verbose=1

)
# Out:
# Epoch 1/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2676 - mae: 0.1540
# Epoch 1: val_loss improved from None to 0.10543, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.1624 - mae: 0.0817 - val_loss: 0.1054 - val_mae: 0.0442 - learning_rate: 0.0010
# Epoch 2/30
# 420/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1023 - mae: 0.0406
# Epoch 2: val_loss improved from 0.10543 to 0.09699, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1005 - mae: 0.0393 - val_loss: 0.0970 - val_mae: 0.0379 - learning_rate: 0.0010
# Epoch 3/30
# 417/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0968 - mae: 0.0367
# Epoch 3: val_loss improved from 0.09699 to 0.09399, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0960 - mae: 0.0362 - val_loss: 0.0940 - val_mae: 0.0355 - learning_rate: 0.0010
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0941 - mae: 0.0349
# Epoch 4: val_loss improved from 0.09399 to 0.09256, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0937 - mae: 0.0345 - val_loss: 0.0926 - val_mae: 0.0343 - learning_rate: 0.0010
# Epoch 5/30
# 417/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0926 - mae: 0.0337
# Epoch 5: val_loss improved from 0.09256 to 0.09160, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0923 - mae: 0.0335 - val_loss: 0.0916 - val_mae: 0.0336 - learning_rate: 0.0010
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0915 - mae: 0.0330
# Epoch 6: val_loss improved from 0.09160 to 0.09102, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0913 - mae: 0.0328 - val_loss: 0.0910 - val_mae: 0.0334 - learning_rate: 0.0010
# Epoch 7/30
# 421/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0908 - mae: 0.0324
# Epoch 7: val_loss improved from 0.09102 to 0.09063, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0906 - mae: 0.0323 - val_loss: 0.0906 - val_mae: 0.0331 - learning_rate: 0.0010
# Epoch 8/30
# 419/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0901 - mae: 0.0319
# Epoch 8: val_loss improved from 0.09063 to 0.09029, saving model to best_model.keras
#
# Epoch 8: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0899 - mae: 0.0318 - val_loss: 0.0903 - val_mae: 0.0328 - learning_rate: 0.0010
# Epoch 9/30
# 418/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0896 - mae: 0.0315
# Epoch 9: val_loss improved from 0.09029 to 0.08992, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0894 - mae: 0.0314 - val_loss: 0.0899 - val_mae: 0.0324 - learning_rate: 0.0010
# Epoch 10/30
# 419/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0891 - mae: 0.0312
# Epoch 10: val_loss improved from 0.08992 to 0.08963, saving model to best_model.keras
#
# Epoch 10: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0889 - mae: 0.0311 - val_loss: 0.0896 - val_mae: 0.0321 - learning_rate: 0.0010
# Epoch 11/30
# 420/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0887 - mae: 0.0309
# Epoch 11: val_loss improved from 0.08963 to 0.08936, saving model to best_model.keras
#
# Epoch 11: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0886 - mae: 0.0308 - val_loss: 0.0894 - val_mae: 0.0319 - learning_rate: 0.0010
# Epoch 12/30
# 420/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0884 - mae: 0.0307
# Epoch 12: val_loss improved from 0.08936 to 0.08910, saving model to best_model.keras
#
# Epoch 12: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0882 - mae: 0.0306 - val_loss: 0.0891 - val_mae: 0.0317 - learning_rate: 0.0010
# Epoch 13/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0881 - mae: 0.0305
# Epoch 13: val_loss improved from 0.08910 to 0.08892, saving model to best_model.keras
#
# Epoch 13: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0879 - mae: 0.0304 - val_loss: 0.0889 - val_mae: 0.0316 - learning_rate: 0.0010
# Epoch 14/30
# 419/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0878 - mae: 0.0303
# Epoch 14: val_loss improved from 0.08892 to 0.08871, saving model to best_model.keras
#
# Epoch 14: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0877 - mae: 0.0302 - val_loss: 0.0887 - val_mae: 0.0313 - learning_rate: 0.0010
# Epoch 15/30
# 418/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0876 - mae: 0.0301
# Epoch 15: val_loss improved from 0.08871 to 0.08859, saving model to best_model.keras
#
# Epoch 15: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0874 - mae: 0.0300 - val_loss: 0.0886 - val_mae: 0.0312 - learning_rate: 0.0010
# Epoch 16/30
# 421/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0873 - mae: 0.0299
# Epoch 16: val_loss improved from 0.08859 to 0.08848, saving model to best_model.keras
#
# Epoch 16: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0872 - mae: 0.0299 - val_loss: 0.0885 - val_mae: 0.0311 - learning_rate: 0.0010
# Epoch 17/30
# 420/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0871 - mae: 0.0298
# Epoch 17: val_loss improved from 0.08848 to 0.08840, saving model to best_model.keras
#
# Epoch 17: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0870 - mae: 0.0297 - val_loss: 0.0884 - val_mae: 0.0310 - learning_rate: 0.0010
# Epoch 18/30
# 417/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0870 - mae: 0.0297
# Epoch 18: val_loss improved from 0.08840 to 0.08839, saving model to best_model.keras
#
# Epoch 18: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0868 - mae: 0.0296 - val_loss: 0.0884 - val_mae: 0.0310 - learning_rate: 0.0010
# Epoch 19/30
# 420/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0868 - mae: 0.0296
# Epoch 19: val_loss improved from 0.08839 to 0.08833, saving model to best_model.keras
#
# Epoch 19: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0867 - mae: 0.0295 - val_loss: 0.0883 - val_mae: 0.0309 - learning_rate: 0.0010
# Epoch 20/30
# 420/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0867 - mae: 0.0294
# Epoch 20: val_loss improved from 0.08833 to 0.08827, saving model to best_model.keras
#
# Epoch 20: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0865 - mae: 0.0294 - val_loss: 0.0883 - val_mae: 0.0308 - learning_rate: 0.0010
# Epoch 21/30
# 419/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0865 - mae: 0.0293
# Epoch 21: val_loss improved from 0.08827 to 0.08826, saving model to best_model.keras
#
# Epoch 21: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0864 - mae: 0.0293 - val_loss: 0.0883 - val_mae: 0.0308 - learning_rate: 0.0010
# Epoch 22/30
# 417/422 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0864 - mae: 0.0293
# Epoch 22: val_loss improved from 0.08826 to 0.08824, saving model to best_model.keras
#
# Epoch 22: finished saving model to best_model.keras
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0863 - mae: 0.0292 - val_loss: 0.0882 - val_mae: 0.0307 - learning_rate: 0.0010
# Epoch 23/30
# 419/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0860 - mae: 0.0290
# Epoch 23: val_loss improved from 0.08824 to 0.08790, saving model to best_model.keras
#
# Epoch 23: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0859 - mae: 0.0289 - val_loss: 0.0879 - val_mae: 0.0307 - learning_rate: 5.0000e-04
# Epoch 24/30
# 417/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0859 - mae: 0.0289
# Epoch 24: val_loss did not improve from 0.08790
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0858 - mae: 0.0289 - val_loss: 0.0879 - val_mae: 0.0307 - learning_rate: 5.0000e-04
# Epoch 25/30
# 417/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0859 - mae: 0.0289
# Epoch 25: val_loss improved from 0.08790 to 0.08787, saving model to best_model.keras
#
# Epoch 25: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0857 - mae: 0.0288 - val_loss: 0.0879 - val_mae: 0.0306 - learning_rate: 5.0000e-04
# Epoch 26/30
# 421/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0858 - mae: 0.0288
# Epoch 26: val_loss did not improve from 0.08787
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0857 - mae: 0.0288 - val_loss: 0.0879 - val_mae: 0.0305 - learning_rate: 5.0000e-04
# Epoch 27/30
# 419/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0856 - mae: 0.0287
# Epoch 27: val_loss did not improve from 0.08787
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0855 - mae: 0.0286 - val_loss: 0.0879 - val_mae: 0.0305 - learning_rate: 2.5000e-04
# Epoch 28/30
# 418/422 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0855 - mae: 0.0287
# Epoch 28: val_loss did not improve from 0.08787
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0854 - mae: 0.0286 - val_loss: 0.0879 - val_mae: 0.0305 - learning_rate: 2.5000e-04
# Epoch 29/30
# 420/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0855 - mae: 0.0287
# Epoch 29: val_loss improved from 0.08787 to 0.08787, saving model to best_model.keras
#
# Epoch 29: finished saving model to best_model.keras
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0854 - mae: 0.0286 - val_loss: 0.0879 - val_mae: 0.0305 - learning_rate: 2.5000e-04
# Epoch 30/30
# 419/422 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0854 - mae: 0.0286
# Epoch 30: val_loss improved from 0.08787 to 0.08739, saving model to best_model.keras
#
# Epoch 30: finished saving model to best_model.keras
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0852 - mae: 0.0285 - val_loss: 0.0874 - val_mae: 0.0302 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 30.

# %% [markdown]
# SAVING MODEL

# %%
autoencoder.save("final_autoencoder.keras")

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %% [markdown]
# TRAINING METRICS

# %%
print("Final Training Loss :",
      history.history["loss"][-1])

print("Final Validation Loss :",
      history.history["val_loss"][-1])

print("Final Training MAE :",
      history.history["mae"][-1])

print("Final Validation MAE :",
      history.history["val_mae"][-1])
# Out:
# Final Training Loss : 0.08524952828884125
# Final Validation Loss : 0.08739425987005234
# Final Training MAE : 0.028465546667575836
# Final Validation MAE : 0.03021794557571411

# %% [markdown]
# PLOTTING TRAINING AND VALIDATION LOSSES

# %%
plt.figure(figsize=(10,5))

plt.plot(history.history["loss"], label="Training Loss", linewidth=2)

plt.plot(history.history["val_loss"], label="Validation Loss", linewidth=2)

plt.title("Training vs Validation Loss", fontsize=15)

plt.xlabel("Epoch")

plt.ylabel("Binary Crossentropy Loss")

plt.legend()

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# PLOTING MAE(MEAN ABSOULTE ERROR)

# %%
plt.figure(figsize=(10,5))

plt.plot(history.history["mae"], label="Training MAE", linewidth=2)

plt.plot(history.history["val_mae"], label="Validation MAE", linewidth=2)

plt.title("Training vs Validation MAE", fontsize=15)

plt.xlabel("Epoch")

plt.ylabel("MAE")

plt.legend()

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# EVALUATING ON TEST DATA

# %%
test_loss, test_mae = autoencoder.evaluate(
    X_test_noisy,
    X_test,
    verbose=1
)

print("="*50)
print(f"Test Loss : {test_loss:.5f}")
print(f"Test MAE  : {test_mae:.5f}")
print("="*50)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0863 - mae: 0.0293
# ==================================================
# Test Loss : 0.08627
# Test MAE  : 0.02926
# ==================================================

# %% [markdown]
# PREDICTING DENOISING IMAGES

# %%
predicted_images = autoencoder.predict(
    X_test_noisy,
    verbose=1
)

print("Prediction Completed")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Prediction Completed

# %% [markdown]
# VISUALIZING IMAGES(ORIGINAL vs NOISY vs DENOISY)

# %%
num_images = 8

plt.figure(figsize=(18,7))

for i in range(num_images):

    # Original Image
    plt.subplot(3, num_images, i+1)

    plt.imshow(X_test[i].squeeze(), cmap="gray")

    plt.title("Original")

    plt.axis("off")


    # Noisy Image
    plt.subplot(3, num_images, i+1+num_images)

    plt.imshow(X_test_noisy[i].squeeze(), cmap="gray")

    plt.title("Noisy")

    plt.axis("off")


    # Reconstructed Image
    plt.subplot(3, num_images, i+1+(2*num_images))

    plt.imshow(predicted_images[i].squeeze(), cmap="gray")

    plt.title("Denoised")

    plt.axis("off")

plt.tight_layout()

plt.show()

# %% [markdown]
# CALCULATING PNSR(Peak Signal-to-Noise Ratio)

# %%
psnr_scores = []

for i in range(len(X_test)):

    score = peak_signal_noise_ratio(
        X_test[i],
        predicted_images[i],
        data_range=1
    )

    psnr_scores.append(score)

average_psnr = np.mean(psnr_scores)

print("="*50)
print(f"Average PSNR : {average_psnr:.2f} dB")
print("="*50)
# Out:
# ==================================================
# Average PSNR : 21.29 dB
# ==================================================

# %% [markdown]
# CALCUTAING SSIM(Structural Similarity Index)

# %%
ssim_scores = []

for i in range(len(X_test)):

    score = structural_similarity(

        X_test[i].squeeze(),

        predicted_images[i].squeeze(),

        data_range=1

    )

    ssim_scores.append(score)

average_ssim = np.mean(ssim_scores)

print("="*50)
print(f"Average SSIM : {average_ssim:.4f}")
print("="*50)
# Out:
# ==================================================
# Average SSIM : 0.9003
# ==================================================

# %% [markdown]
# FINAL RESULTS

# %%
print("="*60)

print("Model Evaluation Summary")

print("="*60)

print(f"Training Loss        : {history.history['loss'][-1]:.5f}")

print(f"Validation Loss      : {history.history['val_loss'][-1]:.5f}")

print(f"Training MAE         : {history.history['mae'][-1]:.5f}")

print(f"Validation MAE       : {history.history['val_mae'][-1]:.5f}")

print(f"Test Loss            : {test_loss:.5f}")

print(f"Test MAE             : {test_mae:.5f}")

print(f"Average PSNR         : {average_psnr:.2f} dB")

print(f"Average SSIM         : {average_ssim:.4f}")

print("="*60)
# Out:
# ============================================================
# Model Evaluation Summary
# ============================================================
# Training Loss        : 0.08525
# Validation Loss      : 0.08739
# Training MAE         : 0.02847
# Validation MAE       : 0.03022
# Test Loss            : 0.08627
# Test MAE             : 0.02926
# Average PSNR         : 21.29 dB
# Average SSIM         : 0.9003
# ============================================================

# %% [markdown]
# SAVING SAMPLE PREDICITON

# %%
plt.figure(figsize=(18,7))

for i in range(8):

    plt.subplot(3,8,i+1)

    plt.imshow(X_test[i].squeeze(), cmap="gray")

    plt.axis("off")


    plt.subplot(3,8,i+9)

    plt.imshow(X_test_noisy[i].squeeze(), cmap="gray")

    plt.axis("off")


    plt.subplot(3,8,i+17)

    plt.imshow(predicted_images[i].squeeze(), cmap="gray")

    plt.axis("off")

plt.tight_layout()

plt.savefig(
    "Denoised_Result.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Image Saved Successfully")
# Out:
# Image Saved Successfully

# %% [markdown]
# SAVING TRAINING GRAPH

# %%
plt.figure(figsize=(10,5))

plt.plot(history.history["loss"], label="Train Loss")

plt.plot(history.history["val_loss"], label="Validation Loss")

plt.legend()

plt.grid(alpha=0.3)

plt.savefig(
    "Training_Curve.png",
    dpi=300
)

plt.show()

print("Training Graph Saved")
# Out:
# Training Graph Saved

# %% [markdown]
# OBSERVATIONS :
# 1. The Convolutional Denoising Autoencoder successfully    reconstructs clean handwritten digits from noisy inputs.
# 2. Training and validation loss decreased steadily, indicating that the model learned meaningful image representations without significant overfitting.
# 3. The average PSNR value indicates good reconstruction quality.
# 4. The reconstructed images retained most of the important structural features while removing Gaussian noise.
# 5. Using convolutional layers instead of dense layers helped preserve spatial information, resulting in better image quality.
